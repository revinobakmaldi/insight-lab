# %% [markdown]
# # QSR Menu Engineering

# %% [markdown]
# Objective: Improve sales through Menu Engineering
#
# How:
# 1. EDA: identify variable which drove more sales
# 1. Menu profiling: identify which menu drove more sales
# 1. Construct new menu composition or configuration
# 1. Develop model to predict sales
# 1. Predict sales

# %% [markdown]
# ## Understanding the data

# %% [markdown]
# ### Import dataset from Kaggle Dataset

# %%
import kagglehub
from kagglehub import KaggleDatasetAdapter

# Set the path to the file you'd like to load
file_path = "qsr_pos_logs.csv"

# Load the latest version
df = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "pratyushpuri/qsr-pos-logs-hotel-menu-modifiers-and-dayparts-2025",
  file_path,
  # Provide any additional arguments like 
  # sql_query or pandas_kwargs. See the 
  # documenation for more information:
  # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterpandas
)
# Out:
# C:\Users\revino.akmaldi\AppData\Local\Temp\ipykernel_15624\8549707.py:8: DeprecationWarning: Use dataset_load() instead of load_dataset(). load_dataset() will be removed in a future version.
#   df = kagglehub.load_dataset(

# %%
df
# Out:
#       order_id  store_id transaction_datetime business_day    daypart  \
# 0       120000       102  2025-07-05 06:14:08   2025-07-05  Breakfast
# 1       120001       201  2025-07-05 11:48:51   2025-07-05      Lunch
# 2       120002       403  2025-04-13 08:05:35   2025-04-13  Breakfast
# 3       120003       301  2025-06-25 06:42:17   2025-06-25  Breakfast
# 4       120004       301  2025-08-01 12:58:36   2025-08-01      Lunch
# ...        ...       ...                  ...          ...        ...
# 1738    121738       102  2025-04-22 10:47:49   2025-04-22  Breakfast
# 1739    121739       301  2025-07-05 16:58:38   2025-07-05  Afternoon
# 1740    121740       101  2025-04-21 15:17:41   2025-04-21  Afternoon
# 1741    121741       403  2025-05-22 12:15:29   2025-05-22      Lunch
# 1742    121742       301  2025-04-20 11:13:39   2025-04-20      Lunch
#
#      service_mode            menu_item    modifier  quantity  unit_price  \
# 0      Drive-Thru        Bottled Water         NaN         1        1.48
# 1         Dine-In     Chicken Sandwich         NaN         1        5.34
# 2         Takeout        Bottled Water   Light Ice         1        1.49
# 3      Drive-Thru           Egg Muffin   No Cheese         1        3.62
# 4      Drive-Thru  Spicy Chicken Combo         NaN         2        9.17
# ...           ...                  ...         ...       ...         ...
# 1738      Dine-In               Coffee      No Ice         2        2.08
# 1739   Drive-Thru          Onion Rings         NaN         4        3.62
# 1740      Dine-In         French Fries         NaN         1        2.61
# 1741      Dine-In         French Fries  Small Size         1        2.59
# 1742   Drive-Thru  Soft Drink (Medium)   Light Ice         3        1.75
#
#       discount   tax  total_amount payment_type
# 0         0.15  0.10          1.43         Cash
# 1         0.00  0.45          5.79         Card
# 2         0.15  0.10          1.44         Cash
# 3         0.00  0.34          3.96         Cash
# 4         0.00  1.38         19.72         Card
# ...        ...   ...           ...          ...
# 1738      0.00  0.35          4.51    MobilePay
# 1739      0.00  1.20         14.48     GiftCard
# 1740      0.52  0.17          2.26         Card
# 1741      0.00  0.22          2.51         Cash
# 1742      0.00  0.37          5.62    MobilePay
#
# [1743 rows x 14 columns]

# %% [markdown]
# ### EDA

# %%
import pandas as pd
from ydata_profiling import ProfileReport

profile = ProfileReport(df, title = 'QSR Data')
profile.to_file('kaggle_qsr_data.html')
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|██████████| 14/14 [00:00<00:00, 100.42it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# **Key informations:**
# - Each order id contains only one menu
# - There are 10 stores
# - Transaction data are from 11-Apr-2025 to 9-Aug-2025
# - Daypart consists Morning, Breakfast, Lunch, Afternoon, Dinner
# - Services mode: Dine-In, Drive-Thru, Takeout, Delivery
# - There are 30 menu item being solde
# - There is modifier column act as notes for each menu
# -
